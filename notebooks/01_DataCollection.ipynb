# %% [markdown]
# # **Notebook 01 — Data Collection**
#
# ## Objectives
#
# * Fetch the credit card fraud dataset from Kaggle using their API
# * Inspect the data: shape, types, class balance, missing values
# * Save the raw dataset to the `data/` folder for use in subsequent notebooks
#
# ## Inputs
#
# * Kaggle API credentials (`kaggle.json`)
# * Dataset identifier: `mlg-ulb/creditcardfraud`
#
# ## Outputs
#
# * `data/creditcard.csv` — raw dataset (284,807 rows × 31 columns)

# %% [markdown]
# ---

# %% [markdown]
# ## Change working directory
#
# We need to change the working directory from the notebook folder to the project root, so that relative paths work correctly throughout the project.

# %%
import os

current_dir = os.getcwd()
print(f"Current directory: {current_dir}")

if current_dir.endswith("notebooks"):
    os.chdir(os.path.dirname(current_dir))

project_root = os.getcwd()
print(f"Working directory set to: {project_root}")
# Out:
# Current directory: C:\Users\name\Desktop\All IN\Code Inst. Projects\credit-card-fraud-detection\notebooks
# Working directory set to: C:\Users\name\Desktop\All IN\Code Inst. Projects\credit-card-fraud-detection

# %% [markdown]
# ## Install and configure Kaggle

# %%
# Install kaggle package
! pip install kaggle

# %%
# Set the Kaggle config directory to the project root
# The kaggle.json file should be placed here before running this cell
os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()

# Set permissions on the kaggle.json file
! chmod 600 kaggle.json
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Set the Kaggle config directory to the project root
#       2 # The kaggle.json file should be placed here before running this cell
# ----> 3 os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()
#       5 # Set permissions on the kaggle.json file
#       6 get_ipython().system(' chmod 600 kaggle.json')
#
# NameError: name 'os' is not defined
