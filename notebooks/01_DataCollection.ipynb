# %% [markdown]
# # **Notebook 01 — Data Collection**
#
# ## Objectives
#
# * Fetch the credit card fraud dataset from Kaggle using their API
# * Inspect the data: shape, types, class balance, missing values
# * Save the raw dataset to the `data/` folder for use in subsequent notebooks
#
# ## Inputs
#
# * Kaggle API credentials (`kaggle.json`)
# * Dataset identifier: `mlg-ulb/creditcardfraud`
#
# ## Outputs
#
# * `data/creditcard.csv` — raw dataset (284,807 rows × 31 columns)

# %% [markdown]
# ---

# %% [markdown]
# ## Change working directory
#
# We need to change the working directory from the notebook folder to the project root, so that relative paths work correctly throughout the project.

# %%
import os

current_dir = os.getcwd()
print(f"Current directory: {current_dir}")

if current_dir.endswith("notebooks"):
    os.chdir(os.path.dirname(current_dir))

project_root = os.getcwd()
print(f"Working directory set to: {project_root}")
# Out:
# Current directory: C:\Users\name\Desktop\All IN\Code Inst. Projects\credit-card-fraud-detection\notebooks
# Working directory set to: C:\Users\name\Desktop\All IN\Code Inst. Projects\credit-card-fraud-detection

# %% [markdown]
# ## Install and configure Kaggle

# %%
# Install kaggle package
! pip install kaggle

# %%
# Set the Kaggle config directory to the project root
# The kaggle.json file should be placed here before running this cell
os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()

# Set permissions on the kaggle.json file
! chmod 600 kaggle.json
# Out:
# 'chmod' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Download the dataset
#
# The dataset comes from the **Machine Learning Group of ULB** (Université Libre de Bruxelles). It contains transactions made by European cardholders in September 2013.
#
# Due to confidentiality, the original features have been transformed using PCA — so we get V1 through V28 as principal components, plus `Time` and `Amount` in their original form.

# %%
# Download and extract the dataset
! kaggle datasets download -d mlg-ulb/creditcardfraud -p data/

# Unzip it
! unzip -o data/creditcardfraud.zip -d data/

# Clean up the zip file
! rm data/creditcardfraud.zip

print("Dataset downloaded successfully.")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# License(s): DbCL-1.0
# ...
#   0%|          | 0.00/66.0M [00:00<?, ?B/s]
# 100%|##########| 66.0M/66.0M [00:00<00:00, 751MB/s]
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.
# Dataset downloaded successfully.
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ---
# ## Load and inspect the data

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("data/creditcard.csv")

print(f"Dataset shape: {df.shape}")
print(f"Total transactions: {df.shape[0]:,}")
print(f"Number of features: {df.shape[1]}")
# Out:
# Dataset shape: (284807, 31)
# Total transactions: 284,807
# Number of features: 31

# %%
# Preview the first few rows
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Check data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# Statistical summary
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
## Class distribution

This is a key thing to check upfront — fraud detection datasets are almost always heavily imbalanced. If there are very few fraud cases relative to legitimate ones, we will need to use techniques like SMOTE during modelling to handle this.
# Out:
#   Cell In[9], line 3
#     This is a key thing to check upfront — fraud detection datasets are almost always heavily imbalanced. If there are very few fraud cases relative to legitimate ones, we will need to use techniques like SMOTE during modelling to handle this.
#                                          ^
# SyntaxError: invalid character '—' (U+2014)

# %%
fraud_count = df['Class'].sum()
legit_count = (df['Class'] == 0).sum()
fraud_pct = df['Class'].mean()

print(f"Legitimate transactions: {legit_count:,} ({1 - fraud_pct:.2%})")
print(f"Fraudulent transactions: {fraud_count:,} ({fraud_pct:.2%})")
print(f"Imbalance ratio: {legit_count // fraud_count}:1")

# %% [markdown]
# ## Missing values check

# %%
missing = df.isnull().sum()
total_missing = missing.sum()

if total_missing == 0:
    print("No missing values found in the dataset.")
else:
    print(f"Total missing values: {total_missing}")
    print(missing[missing > 0])
# Out:
# No missing values found in the dataset.

# %% [markdown]
# ## Duplicate check

# %%
duplicates = df.duplicated().sum()
print(f"Duplicate rows: {duplicates}")

if duplicates > 0:
    dup_mask = df.duplicated(keep=False)
    print(f"  - In fraud class: {df[dup_mask & (df['Class'] == 1)].shape[0]}")
    print(f"  - In legit class: {df[dup_mask & (df['Class'] == 0)].shape[0]}")
    print("Duplicates will be handled in the Data Cleaning notebook.")
# Out:
# Duplicate rows: 1081
#   - In fraud class: 32
#   - In legit class: 1822
# Duplicates will be handled in the Data Cleaning notebook.
